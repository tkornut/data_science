# %%
import os
import csv
import string
import json

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Tokenizer
from nltk.tokenize import WhitespaceTokenizer
# Demo with different tokenizers.
# https://text-processing.com/demo/tokenize/

# %%
# Export mappings to file.
def save_mappings_to_csv_file(folder, filename, word_to_ix, fieldnames = ["word", "index"], show = False):
    """
    Saves mappings dictionary to a file.

    :param filename: File with encodings (absolute path + filename).
    :param word_to_ix: dictionary with word:index keys
    """
    # Expand path.
    folder = os.path.expanduser(folder)
    # Make sure directory exists.
    os.makedirs(os.path.dirname(folder +'/'), exist_ok=True)

    file_path = os.path.join(folder, filename)

    with open(file_path, mode='w+') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        # Create header.
        writer.writeheader()

        # Write word-index pairs.
        for (k,v) in word_to_ix.items():
            if show:
                print("{} : {}".format(k,v))
            writer.writerow({fieldnames[0]:k, fieldnames[1]: v})

# %%
def add_answer_label_to_vocabulary(answer_to_ix, answers):
    """
    Processes answers one by one, treating each as a single label.
    """
    for answer in answers:
        # If new token.
        if answer not in answer_to_ix:
            answer_to_ix[answer] = len(answer_to_ix)
            print("Adding '{}': {}".format(answer, len(answer_to_ix)-1) )

# %%
answer_to_ix = {}

# %%
# Set folders.
data_folder = os.path.expanduser('~/data/gqa')
print(data_folder)
# Out:
# /Users/tomaszkornuta/data/gqa

# %% [markdown]
# ## Play with data

# %%
file = os.path.join(data_folder, "questions", 'val_balanced_questions.json')
with open(file) as f:
    dataset = json.load(f)
print(dataset.keys())
# Out:
# dict_keys(['05515938', '17197213', '08223573', '14778715', '14778714', '1231468', '12143164', '12143165', '19486857', '17284200', '08369253', '05515937', '15962275', '09229761', '13663260', '08321209', '16130590', '11615428', '08185113', '03916612', '08185117', '08185114', '17267240', '101024942', '08185118', '06895964', '09821879', '13571728', '00355883', '14676445', '14676447', '0328071', '03739128', '06645355', '06645358', '04285321', '13112324', '13598462', '0364186', '18555171', '0364188', '08164591', '1942734', '0464559', '0464558', '031007945', '13515212', '17728948', '10889906', '13368729', '151015980', '17284203', '0090767', '17120817', '17819046', '06435607', '06134756', '02315424', '17810030', '13831865', '04819662', '11563995', '12824169', '03260227', '10433179', '16542238', '07603522', '08203407', '09143711', '09143715', '07603528', '09195303', '00805479', '18175193', '02497337', '01163638', '13168817', '13168814', '091013819', '15381074', '18283096', '111015885', '18396310', '091013817', '01532381', '01532383', '17504898', '18924900', '02106577', '16791660', '16718827', '12441069', '1958363', '02247621', '02247623', '1425112', '18435808', '07235616', '07235617', '18798201', '13981103', '18798202', '12661982', '01125115', '15871248', '19436827', '1928517', '04951877', '00297942', '00297941', '00297940', '03635146', '14311593', '09207863', '14738492', '19248065', '171058268', '091055171', '15858851', '07521954', '14903529', '18167292', '10172872', '07241856', '12227132', '07360280', '13708543', '13555503', '11615420', '00562730', '121037755', '08185119', '18167294', '17528426', '00880786', '12409526', '041000077', '00880780', '11119087', '15841623', '09993326', '09993325', '14889408', '02717873', '05107346', '161013365', '181002306', '02717874', '03126814', '07696685', '16552528', '02495704', '09937736', '06434284', '06434281', '06434280', '04403541', '0111303', '05684159', '151001053', '151001050', '12968901', '15693852', '08819990', '151001058', '041037281', '10464328', '06503456', '081020592', '08600971', '06503451', '19779818', '03795448', '1860944', '07745022', '16802826', '07889295', '1131746', '1131747', '08621661', '03177702', '19625432', '09982001', '1654868', '08228442', '15667729', '11215445', '19606703', '03510418', '14732598', '03834173', '02516755', '13695880', '00647234', '14705217', '101001503', '14705211', '14202809', '13598461', '10768721', '14202805', '14202803', '14806825', '01588012', '1463548', '06190513', '11199182', '11199183', '11199180', '00947223', '16644202', '111051819', '16644206', '00681430', '13515709', '06438181', '16997672', '19388466', '0056771', '08749240', '07900409', '14601324', '01476411', '18783554', '07539041', '09282199', '00942617', '15705095', '05189041', '13968256', '06425068', '01343904', '09360669', '18555177', '16344977', '18265883', '02655551', '08223793', '15897583', '16800885', '10972110', '16614293', '15897586', '09128538', '08891674', '00461466', '10620838', '00461461', '00457871', '05672549', '13664499', '05304738', '05672543', '0648000', '05672545', '05672544', '1295575', '101008480', '05499061', '00413042', '16367068', '00927569', '15675504', '12425081', '06874414', '10970140', '13995142', '12425087', '18717754', '16403211', '11292765', '04250744', '00428599', '1946661', '17397396', '00816476', '07490075', '16700319', '041025214', '041025215', '00171614', '13541285', '03150113', '091057558', '171008394', '01974381', '19222090', '16155564', '10956782', '19618200', '14541114', '05444061', '17922184', '14937594', '12534890', '14937597', '02198848', '04243640', '07411217', '10282241', '06790515', '02198843', '01109297', '05454631', '10590264', '10361470', '10590269', '13729280', '05454639', '17454895', '00610246', '16535014', '16713310', '16713312', '02964695', '02964692', '16713315', '02964690', '10274399', '05134715', '04605330', '04235356', '17212637', '18330260', '04605338', '11508318', '12366048', '0526849', '11606870', '04706810', '0699921', '1525059', '1881 ...

# %%
print(len(dataset))
print(dataset['17197213'])
# Out:
# 132062
# {'semantic': [{'operation': 'select', 'dependencies': [], 'argument': 'helmet (3205899)'}, {'operation': 'filter vposition', 'dependencies': [0], 'argument': 'middle'}, {'operation': 'query', 'dependencies': [1], 'argument': 'color'}], 'entailed': ['17197211', '17197212', '17197214', '17197215', '17197221'], 'equivalent': ['17197213'], 'question': 'What color is the helmet in the middle of the image?', 'imageId': '2331963', 'isBalanced': True, 'groups': {'global': 'color', 'local': '10q-helmet_color'}, 'answer': 'light blue', 'semanticStr': 'select: helmet (3205899)->filter vposition: middle [0]->query: color [1]', 'annotations': {'answer': {}, 'question': {'4': '3205899'}, 'fullAnswer': {'1': '3205899'}}, 'types': {'detailed': 'directWhich', 'semantic': 'attr', 'structural': 'query'}, 'fullAnswer': 'The helmet is light blue.'}

# %%
item = dataset['07603522']
for key in item.keys():
    print("{}: {}".format(key, item[key]))
# Out:
# semantic: [{'operation': 'select', 'dependencies': [], 'argument': 'furniture (1337202)'}, {'operation': 'filter size', 'dependencies': [0], 'argument': 'not(small)'}, {'operation': 'choose name', 'dependencies': [1], 'argument': 'table|bed'}]
# entailed: ['07603523']
# equivalent: ['07603522', '07603523']
# question: What piece of furniture is not small, the bed or the table?
# imageId: 2381360
# isBalanced: True
# groups: {'global': 'furniture', 'local': '12c-furniture_n#small'}
# answer: bed
# semanticStr: select: furniture (1337202)->filter size: not(small) [0]->choose name: table|bed [1]
# annotations: {'answer': {'0': '1337202'}, 'question': {'11': '1337204', '8': '1337202', '1:4': '1337204'}, 'fullAnswer': {'1': '1337202'}}
# types: {'detailed': 'categoryThatChoose', 'semantic': 'cat', 'structural': 'choose'}
# fullAnswer: The bed is not small.

# %% [markdown]
# ## Extract vocabulary

# %% [markdown]
# ### Training

# %%
file = os.path.join(data_folder, "questions", "train_all_questions", "train_all_questions_0.json")
with open(file) as f:
    train_dataset = json.load(f)
print(len(train_dataset))
# Out:
# 1430536

# %%
for key,value in train_dataset.items():
    print("key = ",key)
    print("value = ",value)
    break
# Out:
# key =  07333408
# value =  {'semantic': [{'operation': 'select', 'dependencies': [], 'argument': 'wall (722332)'}, {'operation': 'filter color', 'dependencies': [0], 'argument': 'white'}, {'operation': 'relate', 'dependencies': [1], 'argument': '_,on,s (722335)'}, {'operation': 'query', 'dependencies': [2], 'argument': 'name'}], 'entailed': [], 'equivalent': ['07333408'], 'question': 'What is on the white wall?', 'imageId': '2375429', 'isBalanced': True, 'groups': {'global': '', 'local': '14-wall_on,s'}, 'answer': 'pipe', 'semanticStr': 'select: wall (722332)->filter color: white [0]->relate: _,on,s (722335) [1]->query: name [2]', 'annotations': {'answer': {'0': '722335'}, 'question': {'4:6': '722332'}, 'fullAnswer': {'1': '722335', '5': '722332'}}, 'types': {'detailed': 'relS', 'semantic': 'rel', 'structural': 'query'}, 'fullAnswer': 'The pipe is on the wall.'}

# %%
train_answers = [item["answer"] for key, item in train_dataset.items()]
print(train_answers[0:10])
print(len(train_answers))
# Out:
# ['pipe', 'wall', 'white', 'no', 'no', 'white', 'no', 'yes', 'yes', 'yes']
# 1430536

# %%
# Actual loop for loading all training files.
for i in range(10):
    file = os.path.join(data_folder, "questions", "train_all_questions", "train_all_questions_{}.json".format(i))
    with open(file) as f:
        train_dataset = json.load(f)
    print("Loaded {}: {}".format(i, len(train_dataset)))
    # Get all answers.
    train_answers = [item["answer"] for key, item in train_dataset.items()]
    # Add them to vocabulary.
    add_answer_label_to_vocabulary(answer_to_ix, train_answers)
print(len(answer_to_ix))
# Out:
# Loaded:  1430536
# Loaded:  1430536
# Adding 'visitors': 1547
# Adding 'school': 1548
# Adding 'rhinos': 1549
# Adding 'syrup': 1550
# Adding 'heart': 1551
# Adding 'wolf': 1552
# Adding 'sharks': 1553
# Adding 'paper container': 1554
# Adding 'drain': 1555
# Adding 'uniforms': 1556
# Adding 'biscuits': 1557
# Adding 'life jackets': 1558
# Adding 'plantains': 1559
# Adding 'life preserver': 1560
# Adding 'feathers': 1561
# Adding 'whale': 1562
# Adding 'sticks': 1563
# Adding 'milk carton': 1564
# Adding 'clocks': 1565
# Adding 'diaper': 1566
# Adding 'soap bottle': 1567
# Adding 'customer': 1568
# Adding 'music': 1569
# Adding 'amusement park': 1570
# Adding 'doors': 1571
# Adding 'wildflowers': 1572
# Adding 'masks': 1573
# Adding 'scaffolding': 1574
# Adding 'earrings': 1575
# Adding 'marina': 1576
# Adding 'cotton': 1577
# Adding 'wig': 1578
# Adding 'dog food': 1579
# Adding 'shelter': 1580
# Adding 'seagulls': 1581
# Adding 'staircase': 1582
# Adding 'action figure': 1583
# Adding 'towel dispenser': 1584
# Adding 'powder': 1585
# Adding 'dinosaurs': 1586
# Adding 'tags': 1587
# Adding 'heel': 1588
# Adding 'undershirt': 1589
# Adding 'price tag': 1590
# Adding 'bone': 1591
# Adding 'potato salad': 1592
# Adding 'ceiling light': 1593
# Adding 'hammer': 1594
# Adding 'chalkboard': 1595
# Adding 'coats': 1596
# Adding 'fisherman': 1597
# Adding 'grinder': 1598
# Adding 'cowboy hat': 1599
# Adding 'tree branches': 1600
# Adding 'bath towel': 1601
# Adding 'flour': 1602
# Adding 'snake': 1603
# Adding 'banana bunch': 1604
# Adding 'castle': 1605
# Adding 'cranberries': 1606
# Adding 'tents': 1607
# Adding 'kimono': 1608
# Adding 'coarse': 1609
# Adding 'mint': 1610
# Adding 'toothbrushes': 1611
# Adding 'backpacks': 1612
# Adding 'paintings': 1613
# Adding 'family': 1614
# Adding 'cathedral': 1615
# Adding 'chef hat': 1616
# Adding 'sunflowers': 1617
# Adding 'salt': 1618
# Adding 'football': 1619
# Adding 'cookbook': 1620
# Adding 'vinegar': 1621
# Adding 'soap dish': 1622
# Adding 'broom': 1623
# Adding 'crumbs': 1624
# Adding 'tissues': 1625
# Adding 'mustard bottle': 1626
# Adding 'snakes': 1627
# Adding 'video games': 1628
# Adding 'wine bottles': 1629
# Adding 'robot': 1630
# Adding 'toothpicks': 1631
# Adding 'cat food': 1632
# Adding 'fried': 1633
# Adding 'dinner': 1634
# Adding 'hippos': 1635
# Adding 'televisions': 1636
# Adding 'students': 1637
# Adding 'spice': 1638
# Adding 'irregular': 1639
# Adding 'animal': 1640
# Adding 'name tag': 1641
# Adding 'wii game': 1642
# Adding 'ahead': 1643
# Adding 'outfits': 1644
# Adding 'notepad': 1645
# Adding 'flatbread': 1646
# Adding 'banana peel': 1647
# Adding 'garage door': 1648
# Adding 'ice cubes': 1649
# Adding 'away': 1650
# Adding 'wine glasses': 1651
# Adding 'bomb': 1652
# Adding 'soccer': 1653
# Adding 'breakfast': 1654
# Adding 'coffee shop': 1655
# Adding 'baker': 1656
# Adding 'soccer player': 1657
# Adding 'manhole cover': 1658
# Adding 'gift': 1659
# Adding 'pizza shop': 1660
# Adding 'rainbow colored': 1661
# Adding 'parachute': 1662
# Adding 'electric toothbrush': 1663
# Adding 'hats': 1664
# Adding 'ear buds': 1665
# Adding 'cotton candy': 1666
# Adding 'kitchen towel': 1667
# Adding 'coin': 1668
# Adding 'apartment building': 1669
# Adding 'underwear': 1670
# Adding 'underneath': 1671
# Adding 'taking bath': 1672
# Adding 'seed': 1673
# Adding 'back': 1674
# Adding 'picnic tables': 1675
# Adding 'cookie dough': 1676
# Loaded:  1430536
# Adding 'mailbox': 1677
# Adding 'butter knife': 1678
# Adding 'groceries': 1679
# Adding 'pigs': 1680
# Adding 'necklaces': 1681
# Adding 'lizard': 1682
# Adding 'serving dish': 1683
# Adding 'unhappy': 1684
# Adding 'obstacle': 1685
# Adding 'pump': 1686
# Adding 'cigar': 1687
# Adding 'pandas': 1688
# Adding 'cricket': 1689
# Adding 'roasted': 1690
# Adding 'bartender': 1691
# Adding 'unhealthy': 1692
# Adding 'artichokes': 1693
# Adding 'dream catcher': 1694
# Adding 'pistachio': 1695
# Adding 'sideways': 1696
# Adding 'shopping center': 1697
# Adding 'cash register': 1698
# Adding 'ketchup bottle': 1699
# Adding 'stew': 1700
# Adding 'baseball bats': 1701
# Adding 'waitress': 1702
# Adding 'lily': 1703
# Adding 'street lights': 1704
# Adding 'wild': 1705
# Adding 'shoppers': 1706
# Adding 'gym': 1707
# Adding 'egg carton': 1708
# Adding 'buoys': 1709
# Adding 'fine': 1710
# Adding 'games': 1711
# Adding 'bread box': 1712
# Adding 'comb': 1713
# Adding 'outside': 1714
# Adding 'produce': 1715
# Adding 'coconuts': 1716
# Adding 'cemetery': 1717
# Adding 'mugs': 1718
# Adding 'ornaments': 1719
# Adding 'cages': 1720
# Adding 'sponge': 1721
# Adding 'dish soap': 1722
# Adding 'mannequins': 1723
# Adding 'bubbles': 1724
# Adding 'mountain peak': 1725
# Adding 'pesto': 1726
# Adding 'goal': 1727
# Adding 'cranberry': 1728
# Adding 'hearts': 1729
# Adding 'hurdle': 1730
# Adding 'light bulbs': 1731
# Adding 'owls': 1732
# Loaded:  1430536
# Adding 'candle holder': 1733
# Adding 'xbox controller': 1734
# Adding 'dish drainer': 1735
# Adding 'paint brush': 1736
# Adding 'dresses': 1737
# Adding 'beneath': 1738
# Adding 'blossom': 1739
# Adding 'beer mug': 1740
# Adding 'sea foam': 1741
# Adding 'athletic shoe': 1742
# Adding 'kangaroo': 1743
# Adding 'lipstick': 1744
# Adding 'panda bears': 1745
# Adding 'twigs': 1746
# Adding 'shaving cream': 1747
# Adding 'beer can': 1748
# Adding 'bouquet': 1749
# Adding 'shopper': 1750
# Adding 'egg roll': 1751
# Adding 'juice box': 1752
# Adding 'visitor': 1753
# Adding 'coffee beans': 1754
# Adding 'desk lamp': 1755
# Adding 'pub': 1756
# Adding 'ramekin': 1757
# Adding 'sconce': 1758
# Adding 'blood': 1759
# Adding 'storage box': 1760
# Adding 'skateboards': 1761
# Adding 'beer cans': 1762
# Adding 'characters': 1763
# Adding 'cake stand': 1764
# Adding 'napkin dispenser': 1765
# Adding 'taxis': 1766
# Adding 'packages': 1767
# Adding 'scooters': 1768
# Loaded:  1430536
# Adding 'upwards': 1769
# Adding 'waterfall': 1770
# Adding 'coffee cups': 1771
# Adding 'hair clip': 1772
# Adding 'policemen': 1773
# Adding 'batteries': 1774
# Adding 'homes': 1775
# Adding 'antennas': 1776
# Adding 'stir fry': 1777
# Adding 'riding boots': 1778
# Adding 'in the mirror': 1779
# Adding 'lions': 1780
# Adding 'snow boots': 1781
# Adding 'rounded': 1782
# Adding 'jewelry': 1783
# Loaded:  1430536
# Adding 'waiter': 1784
# Adding 'tennis balls': 1785
# Adding 'customers': 1786
# Adding 'pizza tray': 1787
# Adding 'beads': 1788
# Adding 'workers': 1789
# Adding 'sugar packet': 1790
# Adding 'downward': 1791
# Adding 'toasted': 1792
# Adding 'apartment': 1793
# Adding 'bird house': 1794
# Adding 'utensil holder': 1795
# Adding 'dry-erase board': 1796
# Adding 'engineer': 1797
# Adding 'dragons': 1798
# Adding 'snoopy': 1799
# Adding 'hairbrush': 1800
# Adding 'cinnamon': 1801
# Adding 'gas pump': 1802
# Adding 'blossoms': 1803
# Loaded:  1430536
# Adding 'parachutes': 1804
# Adding 'taking photos': 1805
# Adding 'wolves': 1806
# Adding 'boar': 1807
# Adding 'appetizers': 1808
# Adding 'wedding': 1809
# Adding 'tractors': 1810
# Adding 'cookie jar': 1811
# Adding 'battery': 1812
# Adding 'blenders': 1813
# Adding 'paper dispenser': 1814
# Loaded:  1430536
# Adding 'christmas light': 1815
# Adding 'water bottles': 1816
# Adding 'armor': 1817
# Adding 'towers': 1818
# Adding 'waves': 1819
# Adding 'pocket watch': 1820
# Adding 'dolphins': 1821
# Adding 'spray can': 1822
# Adding 'nightstands': 1823
# Adding 'elbow pad': 1824
# Adding 'seat belt': 1825
# Adding 'scrub brush': 1826
# Loaded:  1430536
# Adding 'upward': 1827
# Adding 'tree leaves': 1828
# Adding 'orchid': 1829
# Adding 'dragonfly': 1830
# Adding 'swimmer': 1831
# Adding 'mattresses': 1832
# Adding 'hilltop': 1833
# Adding 'scarce': 1834
# Adding 'vitamins': 1835
# Adding 'immature': 1836
# Loaded:  1430532
# Adding 'appetizer': 1837
# Adding 'dvd players': 1838
# Adding 'pizza crust': 1839
# Adding 'stores': 1840
# Adding 'toolbox': 1841
# Adding 'soccer balls': 1842
# Adding 'lilies': 1843
# Adding 'lab coat': 1844

# %% [markdown]
# ### Validation

# %%
file = os.path.join(data_folder, "questions", "val_all_questions.json")
with open(file) as f:
    val_dataset = json.load(f)
print("Loaded : {}".format(len(val_dataset)))
# Out:
# Loaded : 2011853
# Adding 'pikachu': 1845
# Adding 'wave': 1846
# Adding 'taking notes': 1847
# Adding 'elevator': 1848
# Adding 'shampoo': 1849
# Adding 'horse hoof': 1850
# Adding 'orchids': 1851
# 1852

# %%
# Get all answers.
val_answers = [item["answer"] for key, item in val_dataset.items()]
# Add them to vocabulary.
add_answer_label_to_vocabulary(answer_to_ix, val_answers)
print(len(answer_to_ix))
# Out:
# 1852

# %% [markdown]
# ### Test

# %%
file = os.path.join(data_folder, "questions", "test_all_questions.json")
with open(file) as f:
    test_dataset = json.load(f)
print("Loaded : {}".format(len(test_dataset)))
# Out:
# Loaded : 1340048

# %%
for key,value in test_dataset.items():
    print("key = ",key)
    print("value = ",value)
    break
# Out:
# key =  201971873
# value =  {'isBalanced': False, 'question': 'Is the blanket to the right of a pillow?', 'imageId': 'n15740'}

# %%
# Get all answers.
test_answers = [item["answer"] for key, item in test_dataset.items()]
# Add them to vocabulary.
add_answer_label_to_vocabulary(answer_to_ix, test_answers)
print(len(answer_to_ix))
# Right, no answers here ;)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-a5e45f795861> in <module>
#       1 # Get all answers.
# ----> 2 test_answers = [item["answer"] for key, item in test_dataset.items()]
#       3 # Add them to vocabulary.
#       4 add_answer_label_to_vocabulary(answer_to_ix, test_answers)
#       5 print(len(answer_to_ix))
#
# <ipython-input-31-a5e45f795861> in <listcomp>(.0)
#       1 # Get all answers.
# ----> 2 test_answers = [item["answer"] for key, item in test_dataset.items()]
#       3 # Add them to vocabulary.
#       4 add_answer_label_to_vocabulary(answer_to_ix, test_answers)
#       5 print(len(answer_to_ix))
#
# KeyError: 'answer'

# %% [markdown]
# ## Save vocabulary

# %%
# Generate the name of file.
name = 'answers.all.word.mappings.csv'

print("Saving to: ",name)
# Save to both "destinations."
save_mappings_to_csv_file(data_folder, name, answer_to_ix)
save_mappings_to_csv_file('.', name, answer_to_ix, show = True)
# Out:
# Saving to:  answers.all.word.mappings.csv
# pipe : 0
# wall : 1
# white : 2
# no : 3
# yes : 4
# top : 5
# silver : 6
# black : 7
# right : 8
# man : 9
# left : 10
# large : 11
# chair : 12
# red : 13
# bus : 14
# sweater : 15
# lady : 16
# green : 17
# cow : 18
# herd : 19
# outdoors : 20
# sheep : 21
# end table : 22
# bottom : 23
# train : 24
# carrots : 25
# on : 26
# car : 27
# coat : 28
# blond : 29
# snow : 30
# bag : 31
# jacket : 32
# bench : 33
# girl : 34
# truck : 35
# donut : 36
# long : 37
# elephant : 38
# child : 39
# closed : 40
# bicycle : 41
# concrete : 42
# blue : 43
# seat : 44
# horse : 45
# gray : 46
# glass : 47
# controller : 48
# color : 49
# monitor : 50
# candle : 51
# small : 52
# zebras : 53
# locomotive : 54
# table : 55
# jeans : 56
# plate : 57
# glasses : 58
# metal : 59
# phone : 60
# full : 61
# round : 62
# sword : 63
# vase : 64
# tall : 65
# bedroom : 66
# thin : 67
# shelf : 68
# fence : 69
# trees : 70
# field : 71
# balcony : 72
# wood : 73
# people : 74
# clear : 75
# stop sign : 76
# mannequin : 77
# window : 78
# backpack : 79
# indoors : 80
# checkered : 81
# dish : 82
# dark : 83
# brown : 84
# helmet : 85
# shirt : 86
# road : 87
# low : 88
# building : 89
# chairs : 90
# children : 91
# bushes : 92
# hill : 93
# dog : 94
# basket : 95
# soup : 96
# zebra : 97
# smooth : 98
# down : 99
# cucumber : 100
# lamb : 101
# cell phone : 102
# van : 103
# kettle : 104
# boy : 105
# open : 106
# door : 107
# curtain : 108
